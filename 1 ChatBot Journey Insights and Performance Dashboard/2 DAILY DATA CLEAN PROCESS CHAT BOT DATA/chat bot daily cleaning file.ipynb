# %% [markdown]
# ## Language conversion

# %%
import pandas as pd
from deep_translator import GoogleTranslator
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache
import re

@lru_cache(maxsize=10000)
def translate_text(text, dest='en'):
    """Translate non-English text to English with caching."""
    if is_english_or_numeric(text):
        return text
    try:
        return GoogleTranslator(source='auto', target=dest).translate(text)
    except Exception as e:
        print(f"Translation error: {text} -> {e}")
        return text

def is_english_or_numeric(text):
    return re.match(r'^[a-zA-Z0-9\s.,!?\'"-]*$', text) is not None

def translate_column(column_data):
    return column_data.apply(lambda x: translate_text(str(x)))

def translate_excel_all_sheets(input_file, output_file, sheet_column_map):
    with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
        for sheet_name, columns_to_translate in sheet_column_map.items():
            df = pd.read_excel(input_file, sheet_name=sheet_name)
            translated_df = df.copy()
            with ThreadPoolExecutor(max_workers=len(columns_to_translate)) as executor:
                futures = {
                    executor.submit(translate_column, df[col]): col
                    for col in columns_to_translate if col in df.columns
                }
                for future in futures:
                    col = futures[future]
                    translated_df[f"{col}_translated"] = future.result()
            translated_df.to_excel(writer, sheet_name=sheet_name, index=False)
            print(f"✅ Translated sheet: {sheet_name}")

# === File paths
input_file = r"C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\1 RAW DATA\combine data set.xlsx"
output_file = r"C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\translated_all_sheets.xlsx"

# === Column configuration per sheet
sheet_column_map = {
    'english': ['Language', 'Canton', 'District', 'Gender', 'Scheme', 'Issue'],
    'Français': ['Langue', 'Canton', 'District', 'Sexe', 'Prestation', 'Problème'],
    'Deutsch 1': ['Sprach', 'Kanton', 'Bezirk', 'Geschlecht', 'Leistung', 'Unterstützung'],
    'Deutsch 2': ['Sprach', 'Kanton', 'Bezirk', 'Geschlecht', 'Leistung', 'Unterstützung']
}

# === Run translation
translate_excel_all_sheets(input_file, output_file, sheet_column_map)
# Out:
# ✅ Translated sheet: english
# ✅ Translated sheet: Français
# ✅ Translated sheet: Deutsch 1
# ✅ Translated sheet: Deutsch 2

# %%
df = pd.ExcelFile(output_file)

# %%
print(df.sheet_names)
# Out:
# ['english', 'Français', 'Deutsch 1', 'Deutsch 2']

# %% [markdown]
# ## English column standardization

# %%
df_sheet1 = df.parse('english')

# %%
df_sheet1.head()
# Out:
#                Name            Phone Language            Canton     District  \
# 0   Julie Gutierrez  +41 69 36 44 78  English    Neuchâtel (NE)       Boudry
# 1  Katelyn Santiago  +41 89 28 15 19  English       Geneva (GE)       Geneva
# 2      Edward Moore  +41 89 75 30 08  English       Zurich (ZH)       Zurich
# 3     Megan Jackson  +41 13 10 29 09  English  Basel-Stadt (BS)  Basel-Stadt
# 4    Jesse Thompson  +41 09 05 53 58  English       Geneva (GE)       Geneva
#
#    Gender Age Group                                  Scheme  \
# 0    Male     35–40               Disability Insurance (DI)
# 1  Female     41–46   Health/Accident Insurance (LAMal/LAA)
# 2  Female     35–40  Old-age and Survivors Insurance (OASI)
# 3  Female     53–58   Health/Accident Insurance (LAMal/LAA)
# 4    Male     41–46             Unemployment Insurance (UI)
#
#                     Issue            Timestamp Language_translated  \
# 0            Other reason  05.12.2024 17:22:20             English
# 1  Document/account issue  27.11.2024 06:27:53             English
# 2        Demand for bribe  27.11.2024 20:42:40             English
# 3            Other reason  22.11.2024 16:41:44             English
# 4           Help applying  28.11.2024 02:19:59             English
#
#   Canton_translated District_translated Gender_translated  \
# 0    Neuchâtel (ne)              Boudry              Male
# 1       Geneva (GE)              Geneva            Female
# 2       Zurich (ZH)              Zurich            Female
# 3  Basel-Stadt (BS)         Basel-Stadt            Female
# 4       Geneva (GE)              Geneva              Male
#
#                         Scheme_translated        Issue_translated
# 0               Disability Insurance (by)            Other reason
# 1   Health/Accident Insurance (LAMal/LAA)  Document/account issue
# 2  Old-age and Survivors Insurance (OASI)        Demand for bribe
# 3   Health/Accident Insurance (LAMal/LAA)            Other reason
# 4             Unemployment Insurance (UI)           Help applying

# %%
df_sheet1 = df_sheet1.drop(columns=['Language_translated','Canton_translated','District_translated','Gender_translated','Scheme_translated','Issue_translated'],errors='ignore')

# %%
# Corrected column rename map
column_rename_map = {
    'Phone': 'Mobile Number',
}

# Rename the columns in the DataFrame
df_sheet1.rename(columns=column_rename_map, inplace=True)

# %%
df_sheet1.head()
# Out:
#                Name    Mobile Number Language            Canton     District  \
# 0   Julie Gutierrez  +41 69 36 44 78  English    Neuchâtel (NE)       Boudry
# 1  Katelyn Santiago  +41 89 28 15 19  English       Geneva (GE)       Geneva
# 2      Edward Moore  +41 89 75 30 08  English       Zurich (ZH)       Zurich
# 3     Megan Jackson  +41 13 10 29 09  English  Basel-Stadt (BS)  Basel-Stadt
# 4    Jesse Thompson  +41 09 05 53 58  English       Geneva (GE)       Geneva
#
#    Gender Age Group                                  Scheme  \
# 0    Male     35–40               Disability Insurance (DI)
# 1  Female     41–46   Health/Accident Insurance (LAMal/LAA)
# 2  Female     35–40  Old-age and Survivors Insurance (OASI)
# 3  Female     53–58   Health/Accident Insurance (LAMal/LAA)
# 4    Male     41–46             Unemployment Insurance (UI)
#
#                     Issue            Timestamp
# 0            Other reason  05.12.2024 17:22:20
# 1  Document/account issue  27.11.2024 06:27:53
# 2        Demand for bribe  27.11.2024 20:42:40
# 3            Other reason  22.11.2024 16:41:44
# 4           Help applying  28.11.2024 02:19:59

# %%
new_column_order = [
    "Name", "Mobile Number", "Age Group", "Language", "Gender",
    "Canton", "District", "Scheme", "Issue","Timestamp"
]

# Reorder the columns
df_sheet1 = df_sheet1[new_column_order]

# %%
df25 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\english call center segmentation.xlsx')

# %%
df25
# Out:
#                          Issue       Call center
# 0                 Other reason   Our Call Center
# 1       Document/account issue   Our Call Center
# 2             Demand for bribe  MLA/Party Office
# 3                Help applying   Our Call Center
# 4         Missing approval SMS   Division Office
# 5          Disabled assistance   Division Office
# 6              Pending payment   Our Call Center
# 7                   Form issue  MLA/Party Office
# 8  Website/Application trouble  MLA/Party Office
# 9                Benefit issue   Our Call Center

# %%
df_sheet1 = pd.merge(df_sheet1, df25, on='Issue', how='left')

# %%
df_sheet1.head()
# Out:
#                Name    Mobile Number Age Group Language  Gender  \
# 0   Julie Gutierrez  +41 69 36 44 78     35–40  English    Male
# 1  Katelyn Santiago  +41 89 28 15 19     41–46  English  Female
# 2      Edward Moore  +41 89 75 30 08     35–40  English  Female
# 3     Megan Jackson  +41 13 10 29 09     53–58  English  Female
# 4    Jesse Thompson  +41 09 05 53 58     41–46  English    Male
#
#              Canton     District                                  Scheme  \
# 0    Neuchâtel (NE)       Boudry               Disability Insurance (DI)
# 1       Geneva (GE)       Geneva   Health/Accident Insurance (LAMal/LAA)
# 2       Zurich (ZH)       Zurich  Old-age and Survivors Insurance (OASI)
# 3  Basel-Stadt (BS)  Basel-Stadt   Health/Accident Insurance (LAMal/LAA)
# 4       Geneva (GE)       Geneva             Unemployment Insurance (UI)
#
#                     Issue            Timestamp       Call center
# 0            Other reason  05.12.2024 17:22:20   Our Call Center
# 1  Document/account issue  27.11.2024 06:27:53   Our Call Center
# 2        Demand for bribe  27.11.2024 20:42:40  MLA/Party Office
# 3            Other reason  22.11.2024 16:41:44   Our Call Center
# 4           Help applying  28.11.2024 02:19:59   Our Call Center

# %% [markdown]
# ## French column standardization

# %%
df_sheet2 = df.parse('Français')

# %%
df_sheet2.head()
# Out:
#                 Nom        Téléphone    Langue         Canton  District  \
# 0   Claude Béguelin  +41 61 17 49 01  Français  Fribourg (FR)    Sarine
# 1    Odette Chapuis  +41 10 79 23 88  Français    Valais (VS)     Viège
# 2   Robert Barillon  +41 06 90 09 33  Français   Argovie (AG)     Brugg
# 3   Philippe Martin  +41 09 53 06 62  Français   Soleure (SO)  Thal-Gäu
# 4  Jonathan Mercier  +41 07 81 25 64  Français      Appenzell   Oberegg
#
#     Sexe Tranche d'âge                                Prestation  \
# 0  Homme         41–46    Assurance maladie/accident (LAMal/LAA)
# 1  Femme         47–52                 Assurance invalidité (AI)
# 2  Homme         29–34  Assurance vieillesse et survivants (AVS)
# 3  Homme         23–28                 Assurance invalidité (AI)
# 4  Homme         35–40                    Assurance chômage (AC)
#
#                      Problème           Horodatage Langue_translated  \
# 0       Demande de pot-de-vin  05.11.2024 03:52:40            French
# 1  SMS d'approbation manquant  14.10.2024 17:31:53            French
# 2                Autre raison  28.11.2024 10:14:14            French
# 3                         NaN  19.01.2025 06:01:03            French
# 4                Autre raison  01.01.2025 07:27:26            French
#
#   Canton_translated District_translated Sexe_translated  \
# 0        Fruit (fr)              Sarine           Homme
# 1       Valais (vs)           Threesome           Femme
# 2      Argovie (AG)               Brugg           Homme
# 3         SOOL (SO)            Thal-Gäu           Homme
# 4         Appenzell             Oberegg           Homme
#
#                    Prestation_translated         Problème_translated
# 0  Health/accident insurance (LAMAL/LAA)       Demande de pot-de-vin
# 1              Disability insurance (AI)  SMS d'approbation manquant
# 2  Old age and survivors insurance (AVS)                Autre raison
# 3              Disability insurance (AI)                         NaN
# 4            Unemployment insurance (AC)                Autre raison

# %% [markdown]
# language

# %%
df1 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french language.xlsx')

# %%
df_sheet2 = pd.merge(df_sheet2, df1, on='Langue_translated', how='left')

# %%
df_sheet2 = df_sheet2.drop(columns=['Langue','Langue_translated'],errors='ignore')

# %%
df_sheet2.head(5)
# Out:
#                 Nom        Téléphone         Canton  District   Sexe  \
# 0   Claude Béguelin  +41 61 17 49 01  Fribourg (FR)    Sarine  Homme
# 1    Odette Chapuis  +41 10 79 23 88    Valais (VS)     Viège  Femme
# 2   Robert Barillon  +41 06 90 09 33   Argovie (AG)     Brugg  Homme
# 3   Philippe Martin  +41 09 53 06 62   Soleure (SO)  Thal-Gäu  Homme
# 4  Jonathan Mercier  +41 07 81 25 64      Appenzell   Oberegg  Homme
#
#   Tranche d'âge                                Prestation  \
# 0         41–46    Assurance maladie/accident (LAMal/LAA)
# 1         47–52                 Assurance invalidité (AI)
# 2         29–34  Assurance vieillesse et survivants (AVS)
# 3         23–28                 Assurance invalidité (AI)
# 4         35–40                    Assurance chômage (AC)
#
#                      Problème           Horodatage Canton_translated  \
# 0       Demande de pot-de-vin  05.11.2024 03:52:40        Fruit (fr)
# 1  SMS d'approbation manquant  14.10.2024 17:31:53       Valais (vs)
# 2                Autre raison  28.11.2024 10:14:14      Argovie (AG)
# 3                         NaN  19.01.2025 06:01:03         SOOL (SO)
# 4                Autre raison  01.01.2025 07:27:26         Appenzell
#
#   District_translated Sexe_translated                  Prestation_translated  \
# 0              Sarine           Homme  Health/accident insurance (LAMAL/LAA)
# 1           Threesome           Femme              Disability insurance (AI)
# 2               Brugg           Homme  Old age and survivors insurance (AVS)
# 3            Thal-Gäu           Homme              Disability insurance (AI)
# 4             Oberegg           Homme            Unemployment insurance (AC)
#
#           Problème_translated Language
# 0       Demande de pot-de-vin    French
# 1  SMS d'approbation manquant    French
# 2                Autre raison    French
# 3                         NaN    French
# 4                Autre raison    French

# %% [markdown]
# Gender

# %%
df2 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french_gender.xlsx')

# %%
# Perform the merge
df_sheet2 = pd.merge(df_sheet2, df2, on='Sexe_translated', how='left')

# %%
df_sheet2 = df_sheet2.drop(columns=['Sexe','Sexe_translated'],errors='ignore')

# %%
df_sheet2.head(5)
# Out:
#                 Nom        Téléphone         Canton  District Tranche d'âge  \
# 0   Claude Béguelin  +41 61 17 49 01  Fribourg (FR)    Sarine         41–46
# 1    Odette Chapuis  +41 10 79 23 88    Valais (VS)     Viège         47–52
# 2   Robert Barillon  +41 06 90 09 33   Argovie (AG)     Brugg         29–34
# 3   Philippe Martin  +41 09 53 06 62   Soleure (SO)  Thal-Gäu         23–28
# 4  Jonathan Mercier  +41 07 81 25 64      Appenzell   Oberegg         35–40
#
#                                  Prestation                    Problème  \
# 0    Assurance maladie/accident (LAMal/LAA)       Demande de pot-de-vin
# 1                 Assurance invalidité (AI)  SMS d'approbation manquant
# 2  Assurance vieillesse et survivants (AVS)                Autre raison
# 3                 Assurance invalidité (AI)                         NaN
# 4                    Assurance chômage (AC)                Autre raison
#
#             Horodatage Canton_translated District_translated  \
# 0  05.11.2024 03:52:40        Fruit (fr)              Sarine
# 1  14.10.2024 17:31:53       Valais (vs)           Threesome
# 2  28.11.2024 10:14:14      Argovie (AG)               Brugg
# 3  19.01.2025 06:01:03         SOOL (SO)            Thal-Gäu
# 4  01.01.2025 07:27:26         Appenzell             Oberegg
#
#                    Prestation_translated         Problème_translated  \
# 0  Health/accident insurance (LAMAL/LAA)       Demande de pot-de-vin
# 1              Disability insurance (AI)  SMS d'approbation manquant
# 2  Old age and survivors insurance (AVS)                Autre raison
# 3              Disability insurance (AI)                         NaN
# 4            Unemployment insurance (AC)                Autre raison
#
#   Language   Gender
# 0    French    Male
# 1    French  Female
# 2    French    Male
# 3    French    Male
# 4    French    Male

# %% [markdown]
# scheme

# %%
df3 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french scheme.xlsx')

# %%
df3
# Out:
#                    Prestation_translated  \
# 0  Health/accident insurance (LAMAL/LAA)
# 1              Disability insurance (AI)
# 2  Old age and survivors insurance (AVS)
# 3            Unemployment insurance (AC)
# 4           Professional provident (LPP)
# 5                 Family allowances (AF)
# 6                                    NaN
#
#                                    Scheme
# 0   Health/Accident Insurance (LAMal/LAA)
# 1               Disability Insurance (DI)
# 2  Old-age and Survivors Insurance (OASI)
# 3             Unemployment Insurance (UI)
# 4         Occupational Pension Plan (BVG)
# 5                  Family Allowances (FA)
# 6                                     NaN

# %%
# Perform the merge
df_sheet2 = pd.merge(df_sheet2, df3, on='Prestation_translated', how='left')

# %%
df_sheet2
# Out:
#                             Nom        Téléphone         Canton    District  \
# 0               Claude Béguelin  +41 61 17 49 01  Fribourg (FR)      Sarine
# 1                Odette Chapuis  +41 10 79 23 88    Valais (VS)       Viège
# 2               Robert Barillon  +41 06 90 09 33   Argovie (AG)       Brugg
# 3               Philippe Martin  +41 09 53 06 62   Soleure (SO)    Thal-Gäu
# 4              Jonathan Mercier  +41 07 81 25 64      Appenzell     Oberegg
# ...                         ...              ...            ...         ...
# 419415         Jacques Niquille  +41 38 91 68 43      Vaud (VD)        Nyon
# 419416  Mathilde Cosandey-Meyer  +41 28 01 41 82   Lucerne (LU)    Hochdorf
# 419417            Hélène Beuret  +41 00 32 26 43  Bâle-Campagne  Waldenburg
# 419418      Christophe Bourquin  +41 21 75 07 32  Fribourg (FR)     Singine
# 419419         Liliane Cosendey  +41 07 12 02 91   Grisons (GR)     Bernina
#
#        Tranche d'âge                                Prestation  \
# 0              41–46    Assurance maladie/accident (LAMal/LAA)
# 1              47–52                 Assurance invalidité (AI)
# 2              29–34  Assurance vieillesse et survivants (AVS)
# 3              23–28                 Assurance invalidité (AI)
# 4              35–40                    Assurance chômage (AC)
# ...              ...                                       ...
# 419415         16–22                 Assurance invalidité (AI)
# 419416           >70  Assurance vieillesse et survivants (AVS)
# 419417         53–58                    Assurance chômage (AC)
# 419418         16–22          Prévoyance professionnelle (LPP)
# 419419         23–28               Allocations familiales (AF)
#
#                           Problème           Horodatage Canton_translated  \
# 0            Demande de pot-de-vin  05.11.2024 03:52:40        Fruit (fr)
# 1       SMS d'approbation manquant  14.10.2024 17:31:53       Valais (vs)
# 2                     Autre raison  28.11.2024 10:14:14      Argovie (AG)
# 3                              NaN  19.01.2025 06:01:03         SOOL (SO)
# 4                     Autre raison  01.01.2025 07:27:26         Appenzell
# ...                            ...                  ...               ...
# 419415                Autre raison  19.10.2024 08:17:43         Vaud (VD)
# 419416                Autre raison  19.10.2024 17:32:14      Lucerne (Lu)
# 419417    Assistance pour postuler  01.01.2025 19:13:02    Basel-campaign
# 419418      Problème de formulaire  10.11.2024 03:38:35        Fruit (fr)
# 419419                Autre raison  21.11.2024 02:18:44      Grayons (GR)
#
#        District_translated                  Prestation_translated  \
# 0                   Sarine  Health/accident insurance (LAMAL/LAA)
# 1                Threesome              Disability insurance (AI)
# 2                    Brugg  Old age and survivors insurance (AVS)
# 3                 Thal-Gäu              Disability insurance (AI)
# 4                  Oberegg            Unemployment insurance (AC)
# ...                    ...                                    ...
# 419415                Nyon              Disability insurance (AI)
# 419416            Hochdorf  Old age and survivors insurance (AVS)
# 419417          Waldenburg            Unemployment insurance (AC)
# 419418             Singine           Professional provident (LPP)
# 419419             Bernina                 Family allowances (AF)
#
#                Problème_translated Language   Gender  \
# 0            Demande de pot-de-vin    French    Male
# 1       SMS d'approbation manquant    French  Female
# 2                     Autre raison    French    Male
# 3                              NaN    French    Male
# 4                     Autre raison    French    Male
# ...                            ...       ...     ...
# 419415                Autre raison    French    Male
# 419416                Autre raison    French  Female
# 419417    Assistance pour postuler    French  Female
# 419418                Form problem    French  Female
# 419419                Autre raison    French    Male
#
#                                         Scheme
# 0        Health/Accident Insurance (LAMal/LAA)
# 1                    Disability Insurance (DI)
# 2       Old-age and Survivors Insurance (OASI)
# 3                    Disability Insurance (DI)
# 4                  Unemployment Insurance (UI)
# ...                                        ...
# 419415               Disability Insurance (DI)
# 419416  Old-age and Survivors Insurance (OASI)
# 419417             Unemployment Insurance (UI)
# 419418         Occupational Pension Plan (BVG)
# 419419                  Family Allowances (FA)
#
# [419420 rows x 15 columns]

# %%
df_sheet2 = df_sheet2.drop(columns=['Prestation','Prestation_translated'],errors='ignore')

# %%
df_sheet2
# Out:
#                             Nom        Téléphone         Canton    District  \
# 0               Claude Béguelin  +41 61 17 49 01  Fribourg (FR)      Sarine
# 1                Odette Chapuis  +41 10 79 23 88    Valais (VS)       Viège
# 2               Robert Barillon  +41 06 90 09 33   Argovie (AG)       Brugg
# 3               Philippe Martin  +41 09 53 06 62   Soleure (SO)    Thal-Gäu
# 4              Jonathan Mercier  +41 07 81 25 64      Appenzell     Oberegg
# ...                         ...              ...            ...         ...
# 419415         Jacques Niquille  +41 38 91 68 43      Vaud (VD)        Nyon
# 419416  Mathilde Cosandey-Meyer  +41 28 01 41 82   Lucerne (LU)    Hochdorf
# 419417            Hélène Beuret  +41 00 32 26 43  Bâle-Campagne  Waldenburg
# 419418      Christophe Bourquin  +41 21 75 07 32  Fribourg (FR)     Singine
# 419419         Liliane Cosendey  +41 07 12 02 91   Grisons (GR)     Bernina
#
#        Tranche d'âge                    Problème           Horodatage  \
# 0              41–46       Demande de pot-de-vin  05.11.2024 03:52:40
# 1              47–52  SMS d'approbation manquant  14.10.2024 17:31:53
# 2              29–34                Autre raison  28.11.2024 10:14:14
# 3              23–28                         NaN  19.01.2025 06:01:03
# 4              35–40                Autre raison  01.01.2025 07:27:26
# ...              ...                         ...                  ...
# 419415         16–22                Autre raison  19.10.2024 08:17:43
# 419416           >70                Autre raison  19.10.2024 17:32:14
# 419417         53–58    Assistance pour postuler  01.01.2025 19:13:02
# 419418         16–22      Problème de formulaire  10.11.2024 03:38:35
# 419419         23–28                Autre raison  21.11.2024 02:18:44
#
#        Canton_translated District_translated         Problème_translated  \
# 0             Fruit (fr)              Sarine       Demande de pot-de-vin
# 1            Valais (vs)           Threesome  SMS d'approbation manquant
# 2           Argovie (AG)               Brugg                Autre raison
# 3              SOOL (SO)            Thal-Gäu                         NaN
# 4              Appenzell             Oberegg                Autre raison
# ...                  ...                 ...                         ...
# 419415         Vaud (VD)                Nyon                Autre raison
# 419416      Lucerne (Lu)            Hochdorf                Autre raison
# 419417    Basel-campaign          Waldenburg    Assistance pour postuler
# 419418        Fruit (fr)             Singine                Form problem
# 419419      Grayons (GR)             Bernina                Autre raison
#
#        Language   Gender                                  Scheme
# 0         French    Male   Health/Accident Insurance (LAMal/LAA)
# 1         French  Female               Disability Insurance (DI)
# 2         French    Male  Old-age and Survivors Insurance (OASI)
# 3         French    Male               Disability Insurance (DI)
# 4         French    Male             Unemployment Insurance (UI)
# ...          ...     ...                                     ...
# 419415    French    Male               Disability Insurance (DI)
# 419416    French  Female  Old-age and Survivors Insurance (OASI)
# 419417    French  Female             Unemployment Insurance (UI)
# 419418    French  Female         Occupational Pension Plan (BVG)
# 419419    French    Male                  Family Allowances (FA)
#
# [419420 rows x 13 columns]

# %% [markdown]
# district

# %%
df4 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french_District.xlsx')

# %%
df_sheet2 = pd.merge(df_sheet2, df4, on='District_translated', how='left')

# %%
df_sheet2 = df_sheet2.drop(columns=['District_x','District_translated'],errors='ignore')

# %% [markdown]
# ISSUES

# %%
df5 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french Issue.xlsx')

# %%
df5
# Out:
#            Problème_translated                        Issue
# 0        Demande de pot-de-vin             Demand for bribe
# 1   SMS d'approbation manquant         Missing approval SMS
# 2                 Autre raison                 Other reason
# 3                          NaN                          NaN
# 4     Assistance pour postuler                Help applying
# 5                 Form problem                   Form issue
# 6          Paiement en attente              Pending payment
# 7     Site/Application problem  Website/Application trouble
# 8     Document/account problem       Document/account issue
# 9              Service problem                Benefit issue
# 10               Disabled help          Disabled assistance

# %%
# Perform the merge
df_sheet2 = pd.merge(df_sheet2, df5, on='Problème_translated', how='left')

# %%
df_sheet2 = df_sheet2.drop(columns=['Problème','Problème_translated'],errors='ignore')

# %% [markdown]
# Constituenc

# %%
df6 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\french_Canton.xlsx')

# %%
# Perform the merge
df_sheet2 = pd.merge(df_sheet2, df6, on='Canton_translated', how='left')

# %%
df_sheet2 = df_sheet2.drop(columns=['Canton_x','Canton_translated'],errors='ignore')

# %%
df_sheet2.head(5)
# Out:
#                 Nom        Téléphone Tranche d'âge           Horodatage  \
# 0   Claude Béguelin  +41 61 17 49 01         41–46  05.11.2024 03:52:40
# 1    Odette Chapuis  +41 10 79 23 88         47–52  14.10.2024 17:31:53
# 2   Robert Barillon  +41 06 90 09 33         29–34  28.11.2024 10:14:14
# 3   Philippe Martin  +41 09 53 06 62         23–28  19.01.2025 06:01:03
# 4  Jonathan Mercier  +41 07 81 25 64         35–40  01.01.2025 07:27:26
#
#   Language   Gender                                  Scheme District_y  \
# 0    French    Male   Health/Accident Insurance (LAMal/LAA)     Sarine
# 1    French  Female               Disability Insurance (DI)       Visp
# 2    French    Male  Old-age and Survivors Insurance (OASI)      Brugg
# 3    French    Male               Disability Insurance (DI)   Thal-Gäu
# 4    French    Male             Unemployment Insurance (UI)    Oberegg
#
#                   Issue       Canton_y
# 0      Demand for bribe  Fribourg (FR)
# 1  Missing approval SMS    Valais (VS)
# 2          Other reason    Aargau (AG)
# 3                   NaN            NaN
# 4          Other reason      Appenzell

# %% [markdown]
# renaming column

# %%
# Corrected column rename map
column_rename_map = {
    'Nom': 'Name',
    'Téléphone': 'Mobile Number',
    "Tranche d'âge": 'Age Group',
    'Horodatage': 'Timestamp',   # Renaming 'Update Time' to 'Date'
    'Language': 'Language',
    'Gender': 'Gender',
    'District_y': 'District',
    'Canton_y': 'Canton',

}

# Rename the columns in the DataFrame
df_sheet2.rename(columns=column_rename_map, inplace=True)

# %%
df_sheet2 = df_sheet2.fillna("")

# %%
df_sheet2.head()
# Out:
#                Name    Mobile Number Age Group            Timestamp Language   \
# 0   Claude Béguelin  +41 61 17 49 01     41–46  05.11.2024 03:52:40    French
# 1    Odette Chapuis  +41 10 79 23 88     47–52  14.10.2024 17:31:53    French
# 2   Robert Barillon  +41 06 90 09 33     29–34  28.11.2024 10:14:14    French
# 3   Philippe Martin  +41 09 53 06 62     23–28  19.01.2025 06:01:03    French
# 4  Jonathan Mercier  +41 07 81 25 64     35–40  01.01.2025 07:27:26    French
#
#    Gender                                  Scheme  District  \
# 0    Male   Health/Accident Insurance (LAMal/LAA)    Sarine
# 1  Female               Disability Insurance (DI)      Visp
# 2    Male  Old-age and Survivors Insurance (OASI)     Brugg
# 3    Male               Disability Insurance (DI)  Thal-Gäu
# 4    Male             Unemployment Insurance (UI)   Oberegg
#
#                   Issue         Canton
# 0      Demand for bribe  Fribourg (FR)
# 1  Missing approval SMS    Valais (VS)
# 2          Other reason    Aargau (AG)
# 3
# 4          Other reason      Appenzell

# %%
new_column_order = [
    "Name", "Mobile Number", "Age Group", "Language", "Gender",
    "Canton", "District", "Scheme", "Issue", "Timestamp"
]

# Strip whitespace (just in case)
df_sheet2.columns = df_sheet2.columns.str.strip()

# Filter to only include columns that exist
existing_columns = [col for col in new_column_order if col in df_sheet2.columns]

# Reorder DataFrame
df_sheet2 = df_sheet2[existing_columns]

# %%
df_sheet2 = pd.merge(df_sheet2, df25, on='Issue', how='left')

# %%
df_sheet2.head(5)
# Out:
#                Name    Mobile Number Age Group Language  Gender  \
# 0   Claude Béguelin  +41 61 17 49 01     41–46   French    Male
# 1    Odette Chapuis  +41 10 79 23 88     47–52   French  Female
# 2   Robert Barillon  +41 06 90 09 33     29–34   French    Male
# 3   Philippe Martin  +41 09 53 06 62     23–28   French    Male
# 4  Jonathan Mercier  +41 07 81 25 64     35–40   French    Male
#
#           Canton  District                                  Scheme  \
# 0  Fribourg (FR)    Sarine   Health/Accident Insurance (LAMal/LAA)
# 1    Valais (VS)      Visp               Disability Insurance (DI)
# 2    Aargau (AG)     Brugg  Old-age and Survivors Insurance (OASI)
# 3                 Thal-Gäu               Disability Insurance (DI)
# 4      Appenzell   Oberegg             Unemployment Insurance (UI)
#
#                   Issue            Timestamp       Call center
# 0      Demand for bribe  05.11.2024 03:52:40  MLA/Party Office
# 1  Missing approval SMS  14.10.2024 17:31:53   Division Office
# 2          Other reason  28.11.2024 10:14:14   Our Call Center
# 3                        19.01.2025 06:01:03               NaN
# 4          Other reason  01.01.2025 07:27:26   Our Call Center

# %% [markdown]
# # German column standardization

# %%
df_sheet3 = df.parse('Deutsch 1')
df_sheet4 = df.parse('Deutsch 2')

# %%
df_sheet3.head()
# Out:
#              Name    Telefonnummer   Sprach       Kanton            Bezirk  \
# 0   Marion Ritter  +41 77 07 44 41  Deutsch   Berne (BE)           Seeland
# 1  Predrag Michel  +41 92 76 74 76  Deutsch    Vaud (VD)       Lavaux-Oron
# 2     Dolores Ott  +41 59 00 00 20  Deutsch  Zurich (ZH)            Hinwil
# 3     Maxime Senn  +41 82 43 55 91  Deutsch     Uri (UR)               Uri
# 4   Besim Eugster  +41 43 07 49 16  Deutsch   Berne (BE)  Berne-Mittelland
#
#   Geschlecht Altersgruppe                                      Leistung  \
# 0   Männlich          >70                                           NaN
# 1   Weiblich        35–40                    Invalidenversicherung (IV)
# 2   Weiblich        41–46                Arbeitslosenversicherung (ALV)
# 3   Männlich        47–52                Arbeitslosenversicherung (ALV)
# 4   Männlich        53–58  Alters- und Hinterlassenenversicherung (AHV)
#
#           Unterstützung Aktualisierungszeitpunkt Sprach_translated  \
# 0                   NaN      13.01.2025 11:52:22           Deutsch
# 1   Bestechung verlangt      03.01.2025 18:50:00           Deutsch
# 2  Problem mit Leistung      03.11.2024 04:37:12           Deutsch
# 3  Website-/App-Problem      10.10.2024 22:12:55           Deutsch
# 4    Zahlung ausstehend      16.12.2024 23:48:14           Deutsch
#
#   Kanton_translated Bezirk_translated Geschlecht_translated  \
# 0        Berne (BE)           Seeland             Masculine
# 1         Vaud (VD)       Lavaux-Oron              Weiblich
# 2       Zurich (ZH)            Hinwil              Weiblich
# 3          Uri (ur)               Uri             Masculine
# 4        Berne (BE)  Berne-Mittelland             Masculine
#
#                  Leistung_translated Unterstützung_translated
# 0                                NaN                      NaN
# 1             Invalid insurance (IV)      Bestechung verlangt
# 2       Unemployment insurance (ALV)     Problem mit Leistung
# 3       Unemployment insurance (ALV)     Website-/App-Problem
# 4  Age and left-wing insurance (AHV)       Zahlung ausstehend

# %%
df_sheet4.head()
# Out:
#                  Name    Telefonnummer   Sprach           Kanton       Bezirk  \
# 0    Gil Ziegler-Grob  +41 30 75 21 93  Deutsch  Bâle-Ville (BS)   Bâle-Ville
# 1  Prof. Paul Lehmann  +41 14 42 14 78  Deutsch      Valais (VS)      Rarogne
# 2         Edmund Iten  +41 01 48 57 64  Deutsch        Vaud (VD)  Lavaux-Oron
# 3    Joel Scheidegger  +41 96 23 53 11  Deutsch    Bâle-Campagne   Waldenburg
# 4  Ismet Studer-Imhof  +41 83 71 13 28  Deutsch     Grisons (GR)     Surselva
#
#   Geschlecht Altersgruppe                               Leistung  \
# 0        NaN          NaN                                    NaN
# 1   Männlich        59–64  Kranken-/Unfallversicherung (KVG/UVG)
# 2   Männlich        53–58         Arbeitslosenversicherung (ALV)
# 3   Männlich        47–52                                    NaN
# 4   Weiblich        35–40             Invalidenversicherung (IV)
#
#           Unterstützung Aktualisierungszeitpunkt Sprach_translated  \
# 0                   NaN      19.01.2025 08:31:52           Deutsch
# 1    Zahlung ausstehend      18.01.2025 19:26:04           Deutsch
# 2                   NaN      21.10.2024 00:00:10           Deutsch
# 3                   NaN      03.11.2024 13:38:20           Deutsch
# 4  Problem mit Leistung      12.10.2024 21:15:40           Deutsch
#
#   Kanton_translated Bezirk_translated Geschlecht_translated  \
# 0   Basel-city (BS)        Basel-city                   NaN
# 1       Valais (vs)           Rarogne             Masculine
# 2         Vaud (VD)       Lavaux-Oron             Masculine
# 3    Basel-campaign        Waldenburg             Masculine
# 4      Grayons (GR)          Surselva              Weiblich
#
#                    Leistung_translated Unterstützung_translated
# 0                                  NaN                      NaN
# 1  Health/accident insurance (KVG/UVG)       Zahlung ausstehend
# 2         Unemployment insurance (ALV)                      NaN
# 3                                  NaN                      NaN
# 4               Invalid insurance (IV)     Problem mit Leistung

# %% [markdown]
# language

# %%
df7 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german_Language.xlsx')

# %%
df7
# Out:
#   Sprach_translated Language
# 0           Deutsch  Germany

# %%
df_sheet3 = pd.merge(df_sheet3, df7, on='Sprach_translated', how='left')

# %%
df_sheet4 = pd.merge(df_sheet4, df7, on='Sprach_translated', how='left')

# %%
df_sheet3 = df_sheet3.drop(columns=['Sprach','Sprach_translated'],errors='ignore')

# %%
df_sheet4 = df_sheet4.drop(columns=['Sprach','Sprach_translated'],errors='ignore')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer       Kanton            Bezirk Geschlecht  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)           Seeland   Männlich
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)       Lavaux-Oron   Weiblich
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)            Hinwil   Weiblich
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)               Uri   Männlich
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)  Berne-Mittelland   Männlich
#
#   Altersgruppe                                      Leistung  \
# 0          >70                                           NaN
# 1        35–40                    Invalidenversicherung (IV)
# 2        41–46                Arbeitslosenversicherung (ALV)
# 3        47–52                Arbeitslosenversicherung (ALV)
# 4        53–58  Alters- und Hinterlassenenversicherung (AHV)
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      13.01.2025 11:52:22        Berne (BE)
# 1   Bestechung verlangt      03.01.2025 18:50:00         Vaud (VD)
# 2  Problem mit Leistung      03.11.2024 04:37:12       Zurich (ZH)
# 3  Website-/App-Problem      10.10.2024 22:12:55          Uri (ur)
# 4    Zahlung ausstehend      16.12.2024 23:48:14        Berne (BE)
#
#   Bezirk_translated Geschlecht_translated                Leistung_translated  \
# 0           Seeland             Masculine                                NaN
# 1       Lavaux-Oron              Weiblich             Invalid insurance (IV)
# 2            Hinwil              Weiblich       Unemployment insurance (ALV)
# 3               Uri             Masculine       Unemployment insurance (ALV)
# 4  Berne-Mittelland             Masculine  Age and left-wing insurance (AHV)
#
#   Unterstützung_translated Language
# 0                      NaN  Germany
# 1      Bestechung verlangt  Germany
# 2     Problem mit Leistung  Germany
# 3     Website-/App-Problem  Germany
# 4       Zahlung ausstehend  Germany

# %%
df_sheet4.head(5)
# Out:
#                  Name    Telefonnummer           Kanton       Bezirk  \
# 0    Gil Ziegler-Grob  +41 30 75 21 93  Bâle-Ville (BS)   Bâle-Ville
# 1  Prof. Paul Lehmann  +41 14 42 14 78      Valais (VS)      Rarogne
# 2         Edmund Iten  +41 01 48 57 64        Vaud (VD)  Lavaux-Oron
# 3    Joel Scheidegger  +41 96 23 53 11    Bâle-Campagne   Waldenburg
# 4  Ismet Studer-Imhof  +41 83 71 13 28     Grisons (GR)     Surselva
#
#   Geschlecht Altersgruppe                               Leistung  \
# 0        NaN          NaN                                    NaN
# 1   Männlich        59–64  Kranken-/Unfallversicherung (KVG/UVG)
# 2   Männlich        53–58         Arbeitslosenversicherung (ALV)
# 3   Männlich        47–52                                    NaN
# 4   Weiblich        35–40             Invalidenversicherung (IV)
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      19.01.2025 08:31:52   Basel-city (BS)
# 1    Zahlung ausstehend      18.01.2025 19:26:04       Valais (vs)
# 2                   NaN      21.10.2024 00:00:10         Vaud (VD)
# 3                   NaN      03.11.2024 13:38:20    Basel-campaign
# 4  Problem mit Leistung      12.10.2024 21:15:40      Grayons (GR)
#
#   Bezirk_translated Geschlecht_translated  \
# 0        Basel-city                   NaN
# 1           Rarogne             Masculine
# 2       Lavaux-Oron             Masculine
# 3        Waldenburg             Masculine
# 4          Surselva              Weiblich
#
#                    Leistung_translated Unterstützung_translated Language
# 0                                  NaN                      NaN  Germany
# 1  Health/accident insurance (KVG/UVG)       Zahlung ausstehend  Germany
# 2         Unemployment insurance (ALV)                      NaN  Germany
# 3                                  NaN                      NaN  Germany
# 4               Invalid insurance (IV)     Problem mit Leistung  Germany

# %% [markdown]
# Gender

# %%
df7 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german_gender.xlsx')

# %%
df7.head()
# Out:
#   Geschlecht_translated  Gender
# 0             Masculine    Male
# 1              Weiblich  Female
# 2                   NaN     NaN
# 3                Andere   Other

# %%
# Perform the merge
df_sheet3 = pd.merge(df_sheet3, df7, on='Geschlecht_translated', how='left')

# %%
# Perform the merge
df_sheet4 = pd.merge(df_sheet4, df7, on='Geschlecht_translated', how='left')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer       Kanton            Bezirk Geschlecht  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)           Seeland   Männlich
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)       Lavaux-Oron   Weiblich
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)            Hinwil   Weiblich
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)               Uri   Männlich
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)  Berne-Mittelland   Männlich
#
#   Altersgruppe                                      Leistung  \
# 0          >70                                           NaN
# 1        35–40                    Invalidenversicherung (IV)
# 2        41–46                Arbeitslosenversicherung (ALV)
# 3        47–52                Arbeitslosenversicherung (ALV)
# 4        53–58  Alters- und Hinterlassenenversicherung (AHV)
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      13.01.2025 11:52:22        Berne (BE)
# 1   Bestechung verlangt      03.01.2025 18:50:00         Vaud (VD)
# 2  Problem mit Leistung      03.11.2024 04:37:12       Zurich (ZH)
# 3  Website-/App-Problem      10.10.2024 22:12:55          Uri (ur)
# 4    Zahlung ausstehend      16.12.2024 23:48:14        Berne (BE)
#
#   Bezirk_translated Geschlecht_translated                Leistung_translated  \
# 0           Seeland             Masculine                                NaN
# 1       Lavaux-Oron              Weiblich             Invalid insurance (IV)
# 2            Hinwil              Weiblich       Unemployment insurance (ALV)
# 3               Uri             Masculine       Unemployment insurance (ALV)
# 4  Berne-Mittelland             Masculine  Age and left-wing insurance (AHV)
#
#   Unterstützung_translated Language  Gender
# 0                      NaN  Germany    Male
# 1      Bestechung verlangt  Germany  Female
# 2     Problem mit Leistung  Germany  Female
# 3     Website-/App-Problem  Germany    Male
# 4       Zahlung ausstehend  Germany    Male

# %%
df_sheet3 = df_sheet3.drop(columns=['Geschlecht','Geschlecht_translated'],errors='ignore')

# %%
df_sheet4 = df_sheet4.drop(columns=['Geschlecht','Geschlecht_translated'],errors='ignore')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer       Kanton            Bezirk  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)           Seeland
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)       Lavaux-Oron
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)            Hinwil
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)               Uri
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)  Berne-Mittelland
#
#   Altersgruppe                                      Leistung  \
# 0          >70                                           NaN
# 1        35–40                    Invalidenversicherung (IV)
# 2        41–46                Arbeitslosenversicherung (ALV)
# 3        47–52                Arbeitslosenversicherung (ALV)
# 4        53–58  Alters- und Hinterlassenenversicherung (AHV)
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      13.01.2025 11:52:22        Berne (BE)
# 1   Bestechung verlangt      03.01.2025 18:50:00         Vaud (VD)
# 2  Problem mit Leistung      03.11.2024 04:37:12       Zurich (ZH)
# 3  Website-/App-Problem      10.10.2024 22:12:55          Uri (ur)
# 4    Zahlung ausstehend      16.12.2024 23:48:14        Berne (BE)
#
#   Bezirk_translated                Leistung_translated  \
# 0           Seeland                                NaN
# 1       Lavaux-Oron             Invalid insurance (IV)
# 2            Hinwil       Unemployment insurance (ALV)
# 3               Uri       Unemployment insurance (ALV)
# 4  Berne-Mittelland  Age and left-wing insurance (AHV)
#
#   Unterstützung_translated Language  Gender
# 0                      NaN  Germany    Male
# 1      Bestechung verlangt  Germany  Female
# 2     Problem mit Leistung  Germany  Female
# 3     Website-/App-Problem  Germany    Male
# 4       Zahlung ausstehend  Germany    Male

# %% [markdown]
# scheme

# %%
df8 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german_scheme.xlsx')

# %%
df8
# Out:
#                    Leistung_translated                                  Scheme
# 0                                  NaN                                     NaN
# 1               Invalid insurance (IV)               Disability Insurance (DI)
# 2         Unemployment insurance (ALV)             Unemployment Insurance (UI)
# 3    Age and left-wing insurance (AHV)  Old-age and Survivors Insurance (OASI)
# 4               Family allowances (Fa)                  Family Allowances (FA)
# 5  Health/accident insurance (KVG/UVG)   Health/Accident Insurance (LAMal/LAA)
# 6         Professional provision (BVG)         Occupational Pension Plan (BVG)

# %%
# Perform the merge
df_sheet3 = pd.merge(df_sheet3, df8, on='Leistung_translated', how='left')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer       Kanton            Bezirk  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)           Seeland
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)       Lavaux-Oron
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)            Hinwil
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)               Uri
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)  Berne-Mittelland
#
#   Altersgruppe                                      Leistung  \
# 0          >70                                           NaN
# 1        35–40                    Invalidenversicherung (IV)
# 2        41–46                Arbeitslosenversicherung (ALV)
# 3        47–52                Arbeitslosenversicherung (ALV)
# 4        53–58  Alters- und Hinterlassenenversicherung (AHV)
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      13.01.2025 11:52:22        Berne (BE)
# 1   Bestechung verlangt      03.01.2025 18:50:00         Vaud (VD)
# 2  Problem mit Leistung      03.11.2024 04:37:12       Zurich (ZH)
# 3  Website-/App-Problem      10.10.2024 22:12:55          Uri (ur)
# 4    Zahlung ausstehend      16.12.2024 23:48:14        Berne (BE)
#
#   Bezirk_translated                Leistung_translated  \
# 0           Seeland                                NaN
# 1       Lavaux-Oron             Invalid insurance (IV)
# 2            Hinwil       Unemployment insurance (ALV)
# 3               Uri       Unemployment insurance (ALV)
# 4  Berne-Mittelland  Age and left-wing insurance (AHV)
#
#   Unterstützung_translated Language  Gender  \
# 0                      NaN  Germany    Male
# 1      Bestechung verlangt  Germany  Female
# 2     Problem mit Leistung  Germany  Female
# 3     Website-/App-Problem  Germany    Male
# 4       Zahlung ausstehend  Germany    Male
#
#                                    Scheme
# 0                                     NaN
# 1               Disability Insurance (DI)
# 2             Unemployment Insurance (UI)
# 3             Unemployment Insurance (UI)
# 4  Old-age and Survivors Insurance (OASI)

# %%
# Perform the merge
df_sheet4 = pd.merge(df_sheet4, df8, on='Leistung_translated', how='left')

# %%
df_sheet3 = df_sheet3.drop(columns=['Leistung','Leistung_translated'],errors='ignore')

# %%
df_sheet4 = df_sheet4.drop(columns=['Leistung','Leistung_translated'],errors='ignore')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer       Kanton            Bezirk  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)           Seeland
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)       Lavaux-Oron
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)            Hinwil
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)               Uri
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)  Berne-Mittelland
#
#   Altersgruppe         Unterstützung Aktualisierungszeitpunkt  \
# 0          >70                   NaN      13.01.2025 11:52:22
# 1        35–40   Bestechung verlangt      03.01.2025 18:50:00
# 2        41–46  Problem mit Leistung      03.11.2024 04:37:12
# 3        47–52  Website-/App-Problem      10.10.2024 22:12:55
# 4        53–58    Zahlung ausstehend      16.12.2024 23:48:14
#
#   Kanton_translated Bezirk_translated Unterstützung_translated Language  \
# 0        Berne (BE)           Seeland                      NaN  Germany
# 1         Vaud (VD)       Lavaux-Oron      Bestechung verlangt  Germany
# 2       Zurich (ZH)            Hinwil     Problem mit Leistung  Germany
# 3          Uri (ur)               Uri     Website-/App-Problem  Germany
# 4        Berne (BE)  Berne-Mittelland       Zahlung ausstehend  Germany
#
#    Gender                                  Scheme
# 0    Male                                     NaN
# 1  Female               Disability Insurance (DI)
# 2  Female             Unemployment Insurance (UI)
# 3    Male             Unemployment Insurance (UI)
# 4    Male  Old-age and Survivors Insurance (OASI)

# %% [markdown]
# district

# %%
df9 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german_District.xlsx')

# %%
df9
# Out:
#     Bezirk_translated     District
# 0           Affoltern    Affoltern
# 1               Aigle        Aigle
# 2              Albula       Albula
# 3         Andelfingen  Andelfingen
# 4           Appenzell    Appenzell
# ..                ...          ...
# 123               Wil          Wil
# 124          Willisau     Willisau
# 125       Winterthour   Winterthur
# 126              Zoug          Zug
# 127            Zurich       Zurich
#
# [128 rows x 2 columns]

# %%
df_sheet3 = pd.merge(df_sheet3, df9, on='Bezirk_translated', how='left')

# %%
df_sheet4 = pd.merge(df_sheet4, df9, on='Bezirk_translated', how='left')

# %%
df_sheet4 = df_sheet4.drop(columns=['Bezirk_translated','Bezirk'],errors='ignore')

# %%
df_sheet3 = df_sheet3.drop(columns=['Bezirk','Bezirk_translated'],errors='ignore')

# %%
df_sheet3.head()
# Out:
#              Name    Telefonnummer       Kanton Altersgruppe  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)          >70
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)        35–40
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)        41–46
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)        47–52
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)        53–58
#
#           Unterstützung Aktualisierungszeitpunkt Kanton_translated  \
# 0                   NaN      13.01.2025 11:52:22        Berne (BE)
# 1   Bestechung verlangt      03.01.2025 18:50:00         Vaud (VD)
# 2  Problem mit Leistung      03.11.2024 04:37:12       Zurich (ZH)
# 3  Website-/App-Problem      10.10.2024 22:12:55          Uri (ur)
# 4    Zahlung ausstehend      16.12.2024 23:48:14        Berne (BE)
#
#   Unterstützung_translated Language  Gender  \
# 0                      NaN  Germany    Male
# 1      Bestechung verlangt  Germany  Female
# 2     Problem mit Leistung  Germany  Female
# 3     Website-/App-Problem  Germany    Male
# 4       Zahlung ausstehend  Germany    Male
#
#                                    Scheme         District
# 0                                     NaN          Seeland
# 1               Disability Insurance (DI)      Lavaux-Oron
# 2             Unemployment Insurance (UI)           Hinwil
# 3             Unemployment Insurance (UI)              Uri
# 4  Old-age and Survivors Insurance (OASI)  Bern-Mittelland

# %% [markdown]
# ISSUES

# %%
df10 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german _issue.xlsx')

# %%
df10
# Out:
#     Unterstützung_translated                        Issue
# 0        Bestechung verlangt             Demand for bribe
# 1       Problem mit Leistung                Benefit issue
# 2       Website-/App-Problem  Website/Application trouble
# 3         Zahlung ausstehend              Pending payment
# 4           Hilfe bei Antrag                Help applying
# 5           Behindertenhilfe          Disabled assistance
# 6            Formularproblem                   Form issue
# 7              Anderer Grund                 Other reason
# 8  SMS zur Genehmigung fehlt         Missing approval SMS
# 9   Document- / bank problem       Document/account issue

# %%
# Perform the merge
df_sheet3 = pd.merge(df_sheet3, df10, on='Unterstützung_translated', how='left')

# %%
# Perform the merge
df_sheet4 = pd.merge(df_sheet4, df10, on='Unterstützung_translated', how='left')

# %%
df_sheet3 = df_sheet3.drop(columns=['Unterstützung','Unterstützung_translated'],errors='ignore')

# %%
df_sheet4 = df_sheet4.drop(columns=['Unterstützung','Unterstützung_translated'],errors='ignore')

# %%
df_sheet3.head()
# Out:
#              Name    Telefonnummer       Kanton Altersgruppe  \
# 0   Marion Ritter  +41 77 07 44 41   Berne (BE)          >70
# 1  Predrag Michel  +41 92 76 74 76    Vaud (VD)        35–40
# 2     Dolores Ott  +41 59 00 00 20  Zurich (ZH)        41–46
# 3     Maxime Senn  +41 82 43 55 91     Uri (UR)        47–52
# 4   Besim Eugster  +41 43 07 49 16   Berne (BE)        53–58
#
#   Aktualisierungszeitpunkt Kanton_translated Language  Gender  \
# 0      13.01.2025 11:52:22        Berne (BE)  Germany    Male
# 1      03.01.2025 18:50:00         Vaud (VD)  Germany  Female
# 2      03.11.2024 04:37:12       Zurich (ZH)  Germany  Female
# 3      10.10.2024 22:12:55          Uri (ur)  Germany    Male
# 4      16.12.2024 23:48:14        Berne (BE)  Germany    Male
#
#                                    Scheme         District  \
# 0                                     NaN          Seeland
# 1               Disability Insurance (DI)      Lavaux-Oron
# 2             Unemployment Insurance (UI)           Hinwil
# 3             Unemployment Insurance (UI)              Uri
# 4  Old-age and Survivors Insurance (OASI)  Bern-Mittelland
#
#                          Issue
# 0                          NaN
# 1             Demand for bribe
# 2                Benefit issue
# 3  Website/Application trouble
# 4              Pending payment

# %% [markdown]
# conton

# %%
df11 = pd.read_excel(r'C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\Columns File\german_Canton.xlsx')

# %%
df11
# Out:
#    Kanton_translated             Canton
# 0          Appenzell          Appenzell
# 1      Bâle-Campagne   Basel-Landschaft
# 2    Bâle-Ville (BS)   Basel-Stadt (BS)
# 3         Berne (BE)          Bern (BE)
# 4      Fribourg (FR)      Fribourg (FR)
# 5        Genève (GE)        Geneva (GE)
# 6        Glaris (GL)        Glarus (GL)
# 7       Grisons (GR)       Grisons (GR)
# 8          Jura (JU)          Jura (JU)
# 9       Lucerne (LU)       Lucerne (LU)
# 10    Neuchâtel (NE)     Neuchâtel (NE)
# 11      Nidwald (NW)     Nidwalden (NW)
# 12       Obwald (OW)      Obwalden (OW)
# 13   Saint-Gall (SG)    St. Gallen (SG)
# 14  Schaffhouse (SH)  Schaffhausen (SH)
# 15      Schwytz (SZ)        Schwyz (SZ)
# 16      Soleure (SO)     Solothurn (SO)
# 17       Tessin (TI)        Ticino (TI)
# 18    Thurgovie (TG)       Thurgau (TG)
# 19          Uri (UR)           Uri (UR)
# 20       Valais (VS)        Valais (VS)
# 21         Vaud (VD)          Vaud (VD)
# 22         Zoug (ZG)           Zug (ZG)
# 23       Zurich (ZH)        Zurich (ZH)

# %%
# Perform the merge
df_sheet3 = pd.merge(df_sheet3, df11, on='Kanton_translated', how='left')

# %%
# Perform the merge
df_sheet4 = pd.merge(df_sheet4, df11, on='Kanton_translated', how='left')

# %%
df_sheet3 = df_sheet3.drop(columns=['Kanton_translated','Kanton'],errors='ignore')

# %%
df_sheet4 = df_sheet4.drop(columns=['Kanton_translated','Kanton'],errors='ignore')

# %%
df_sheet3.head(5)
# Out:
#              Name    Telefonnummer Altersgruppe Aktualisierungszeitpunkt  \
# 0   Marion Ritter  +41 77 07 44 41          >70      13.01.2025 11:52:22
# 1  Predrag Michel  +41 92 76 74 76        35–40      03.01.2025 18:50:00
# 2     Dolores Ott  +41 59 00 00 20        41–46      03.11.2024 04:37:12
# 3     Maxime Senn  +41 82 43 55 91        47–52      10.10.2024 22:12:55
# 4   Besim Eugster  +41 43 07 49 16        53–58      16.12.2024 23:48:14
#
#   Language  Gender                                  Scheme         District  \
# 0  Germany    Male                                     NaN          Seeland
# 1  Germany  Female               Disability Insurance (DI)      Lavaux-Oron
# 2  Germany  Female             Unemployment Insurance (UI)           Hinwil
# 3  Germany    Male             Unemployment Insurance (UI)              Uri
# 4  Germany    Male  Old-age and Survivors Insurance (OASI)  Bern-Mittelland
#
#                          Issue       Canton
# 0                          NaN    Bern (BE)
# 1             Demand for bribe    Vaud (VD)
# 2                Benefit issue  Zurich (ZH)
# 3  Website/Application trouble          NaN
# 4              Pending payment    Bern (BE)

# %% [markdown]
# renaming column

# %%
# Corrected column rename map
column_rename_map = {
    'Name': 'Name',
    'Telefonnummer': 'Mobile Number',
    "Altersgruppe": 'Age Group',
    'Aktualisierungszeitpunkt': 'Timestamp',   # Renaming 'Update Time' to 'Date'
    'Language': 'Language',
    'Gender': 'Gender',
    'District_y': 'District',
    'Canton_y': 'Canton',

}

# Rename the columns in the DataFrame
df_sheet3.rename(columns=column_rename_map, inplace=True)
df_sheet4.rename(columns=column_rename_map, inplace=True)

# %%
df_sheet3 = df_sheet3.fillna("")
df_sheet4 = df_sheet4.fillna("")

# %%
df_sheet3.head(5)
# Out:
#              Name    Mobile Number Age Group            Timestamp Language  \
# 0   Marion Ritter  +41 77 07 44 41       >70  13.01.2025 11:52:22  Germany
# 1  Predrag Michel  +41 92 76 74 76     35–40  03.01.2025 18:50:00  Germany
# 2     Dolores Ott  +41 59 00 00 20     41–46  03.11.2024 04:37:12  Germany
# 3     Maxime Senn  +41 82 43 55 91     47–52  10.10.2024 22:12:55  Germany
# 4   Besim Eugster  +41 43 07 49 16     53–58  16.12.2024 23:48:14  Germany
#
#    Gender                                  Scheme         District  \
# 0    Male                                                  Seeland
# 1  Female               Disability Insurance (DI)      Lavaux-Oron
# 2  Female             Unemployment Insurance (UI)           Hinwil
# 3    Male             Unemployment Insurance (UI)              Uri
# 4    Male  Old-age and Survivors Insurance (OASI)  Bern-Mittelland
#
#                          Issue       Canton
# 0                                 Bern (BE)
# 1             Demand for bribe    Vaud (VD)
# 2                Benefit issue  Zurich (ZH)
# 3  Website/Application trouble
# 4              Pending payment    Bern (BE)

# %%
df_sheet4.head()
# Out:
#                  Name    Mobile Number Age Group            Timestamp  \
# 0    Gil Ziegler-Grob  +41 30 75 21 93            19.01.2025 08:31:52
# 1  Prof. Paul Lehmann  +41 14 42 14 78     59–64  18.01.2025 19:26:04
# 2         Edmund Iten  +41 01 48 57 64     53–58  21.10.2024 00:00:10
# 3    Joel Scheidegger  +41 96 23 53 11     47–52  03.11.2024 13:38:20
# 4  Ismet Studer-Imhof  +41 83 71 13 28     35–40  12.10.2024 21:15:40
#
#   Language  Gender                                 Scheme     District  \
# 0  Germany                                                 Basel-Stadt
# 1  Germany    Male  Health/Accident Insurance (LAMal/LAA)      Rarogne
# 2  Germany    Male            Unemployment Insurance (UI)  Lavaux-Oron
# 3  Germany    Male                                          Waldenburg
# 4  Germany  Female              Disability Insurance (DI)     Surselva
#
#              Issue     Canton
# 0
# 1  Pending payment
# 2                   Vaud (VD)
# 3
# 4    Benefit issue

# %%
# Corrected column rename map
column_rename_map = {
    'Language_x': 'Language',
}

# Rename the columns in the DataFrame

df_sheet4.rename(columns=column_rename_map, inplace=True)
df_sheet4 = df_sheet4.drop(columns=['Language_y'],errors='ignore')

# %%
new_column_order = [
    "Name", "Mobile Number", "Age Group", "Language", "Gender",
    "Canton", "District", "Scheme", "Issue","Timestamp"
]

# Reorder the columns
df_sheet3 = df_sheet3[new_column_order]
df_sheet4 = df_sheet4[new_column_order]

# %%
df_sheet3 = pd.merge(df_sheet3, df25, on='Issue', how='left')

# %%
df_sheet4 = pd.merge(df_sheet4, df25, on='Issue', how='left')

# %%
df_sheet3.head(5)
# Out:
#              Name    Mobile Number Age Group Language  Gender       Canton  \
# 0   Marion Ritter  +41 77 07 44 41       >70  Germany    Male    Bern (BE)
# 1  Predrag Michel  +41 92 76 74 76     35–40  Germany  Female    Vaud (VD)
# 2     Dolores Ott  +41 59 00 00 20     41–46  Germany  Female  Zurich (ZH)
# 3     Maxime Senn  +41 82 43 55 91     47–52  Germany    Male
# 4   Besim Eugster  +41 43 07 49 16     53–58  Germany    Male    Bern (BE)
#
#           District                                  Scheme  \
# 0          Seeland
# 1      Lavaux-Oron               Disability Insurance (DI)
# 2           Hinwil             Unemployment Insurance (UI)
# 3              Uri             Unemployment Insurance (UI)
# 4  Bern-Mittelland  Old-age and Survivors Insurance (OASI)
#
#                          Issue            Timestamp       Call center
# 0                               13.01.2025 11:52:22               NaN
# 1             Demand for bribe  03.01.2025 18:50:00  MLA/Party Office
# 2                Benefit issue  03.11.2024 04:37:12   Our Call Center
# 3  Website/Application trouble  10.10.2024 22:12:55  MLA/Party Office
# 4              Pending payment  16.12.2024 23:48:14   Our Call Center

# %%
df_sheet4.head(5)
# Out:
#                  Name    Mobile Number Age Group Language  Gender     Canton  \
# 0    Gil Ziegler-Grob  +41 30 75 21 93            Germany
# 1  Prof. Paul Lehmann  +41 14 42 14 78     59–64  Germany    Male
# 2         Edmund Iten  +41 01 48 57 64     53–58  Germany    Male  Vaud (VD)
# 3    Joel Scheidegger  +41 96 23 53 11     47–52  Germany    Male
# 4  Ismet Studer-Imhof  +41 83 71 13 28     35–40  Germany  Female
#
#       District                                 Scheme            Issue  \
# 0  Basel-Stadt
# 1      Rarogne  Health/Accident Insurance (LAMal/LAA)  Pending payment
# 2  Lavaux-Oron            Unemployment Insurance (UI)
# 3   Waldenburg
# 4     Surselva              Disability Insurance (DI)    Benefit issue
#
#              Timestamp      Call center
# 0  19.01.2025 08:31:52              NaN
# 1  18.01.2025 19:26:04  Our Call Center
# 2  21.10.2024 00:00:10              NaN
# 3  03.11.2024 13:38:20              NaN
# 4  12.10.2024 21:15:40  Our Call Center

# %% [markdown]
# ## Export to excel

# %%
# Replace 'output_file.xlsx' with your desired filename
output_file = r"C:\Users\hp\Desktop\Github\Power-BI\1 ChatBot Journey Insights and Performance Dashboard\2 DAILY DATA CLEAN PROCESS CHAT BOT DATA\output_file_final.xlsx"
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    df_sheet1.to_excel(writer, sheet_name='Sheet1', index=False)
    df_sheet2.to_excel(writer, sheet_name='Sheet2', index=False)
    df_sheet3.to_excel(writer, sheet_name='Sheet3', index=False)
    df_sheet4.to_excel(writer, sheet_name='Sheet4', index=False)
